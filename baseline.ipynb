# %% [markdown]
# ## 1. Import

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[1], line 7
#       4 from sklearn.metrics import f1_score
#       6 from sklearn.preprocessing import OneHotEncoder
# ----> 7 from xgboost import XGBClassifier
#       8 import warnings
#       9 warnings.filterwarnings(action='ignore')
#
# File ~/dacon/.venv/lib/python3.10/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective, dask
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)
#      15     build_info,
#      16 )
#
# File ~/dacon/.venv/lib/python3.10/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/dacon/.venv/lib/python3.10/site-packages/xgboost/core.py:269
#     265     return lib
#     268 # load the XGBoost library globally
# --> 269 _LIB = _load_lib()
#     272 def _check_call(ret: int) -> None:
#     273     """Check the return value of C API call
#     274
#     275     This function will raise exception when error occurs.
#    (...)
#     281         return value from API calls
#     282     """
#
# File ~/dacon/.venv/lib/python3.10/site-packages/xgboost/core.py:222, in _load_lib()
#     220     if not lib_success:
#     221         libname = os.path.basename(lib_paths[0])
# --> 222         raise XGBoostError(
#     223             f"""
#     224 XGBoost Library ({libname}) could not be loaded.
#     225 Likely causes:
#     226   * OpenMP runtime is not installed
#     227     - vcomp140.dll or libgomp-1.dll for Windows
#     228     - libomp.dylib for Mac OSX
#     229     - libgomp.so for Linux and other UNIX-like OSes
#     230     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     231
#     232   * You are running 32-bit Python on a 64-bit OS
#     233
#     234 Error message(s): {os_error_list}
#     235 """
#     236         )
#     237     _register_log_callback(lib)
#     239     def parse(ver: str) -> Tuple[int, int, int]:
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ["dlopen(/Users/jinushin/dacon/.venv/lib/python3.10/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: @rpath/libomp.dylib\n  Referenced from: <89AD948E-E564-3266-867D-7AF89D6488F0> /Users/jinushin/dacon/.venv/lib/python3.10/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file)"]

# %% [markdown]
# ## 2. Data Load

# %%
# 학습/평가 데이터 로드
train_df = pd.read_csv('open/train.csv').drop(columns=['UID'])
test_df = pd.read_csv('open/test.csv').drop(columns=['UID'])

# %% [markdown]
# ## 3. Pre-processing (전처리)

# %%
categorical_col = [
    '주거 형태',
    '현재 직장 근속 연수',
    '대출 목적',
    '대출 상환 기간'
]

# OneHotEncoder 초기화
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# 훈련 데이터에 대해 인코더 학습
encoder.fit(train_df[categorical_col])

# 훈련 데이터와 테스트 데이터 변환
train_encoded = encoder.transform(train_df[categorical_col])
test_encoded = encoder.transform(test_df[categorical_col])

# One-hot encoding 결과를 데이터프레임으로 변환
train_encoded_df = pd.DataFrame(train_encoded, columns=encoder.get_feature_names_out(categorical_col))
test_encoded_df = pd.DataFrame(test_encoded, columns=encoder.get_feature_names_out(categorical_col))

# 인코딩된 결과를 원래 데이터에 적용
train_df = pd.concat([train_df.drop(columns=categorical_col).reset_index(drop=True), train_encoded_df], axis=1)
test_df = pd.concat([test_df.drop(columns=categorical_col).reset_index(drop=True), test_encoded_df], axis=1)

# %% [markdown]
# ## 4. Train / Validation Split (학습 데이터 분할)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    train_df.drop(columns=['채무 불이행 여부']), 
    train_df['채무 불이행 여부'], 
    test_size=0.2, 
    random_state=42
)

# %% [markdown]
# ## 5. Model Training (모델 학습)

# %%
# XGBoost 모델 학습
model = XGBClassifier(
    n_estimators=10,  # 트리 개수
    max_depth=5,       # 최대 깊이
    learning_rate=0.15, # 학습률
    random_state=42,
    use_label_encoder=False,  # 경고 방지
    eval_metric="auc",        # 평가 지표 설정
    early_stopping_rounds=10 
)

# %%
# 학습 및 Validation 성능 모니터링
eval_set = [(X_train, y_train), (X_val, y_val)]
model.fit(
    X_train, y_train,
    eval_set=eval_set,
    verbose=True,  # 학습 로그 출력
     # 5번의 학습 동안 성능 개선 없을 시 조기 종료
)
# Out:
# [0]	validation_0-auc:0.73056	validation_1-auc:0.67897
# [1]	validation_0-auc:0.74434	validation_1-auc:0.69985
# [2]	validation_0-auc:0.75222	validation_1-auc:0.70013
# [3]	validation_0-auc:0.75962	validation_1-auc:0.70342
# [4]	validation_0-auc:0.76341	validation_1-auc:0.70646
# [5]	validation_0-auc:0.76785	validation_1-auc:0.70622
# [6]	validation_0-auc:0.77482	validation_1-auc:0.71070
# [7]	validation_0-auc:0.78105	validation_1-auc:0.71547
# [8]	validation_0-auc:0.78692	validation_1-auc:0.71940
# [9]	validation_0-auc:0.78952	validation_1-auc:0.72130
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.15, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
from xgboost import XGBClassifier, callback
# 조기 종료 콜백 설정
early_stopping = callback.EarlyStopping(
    rounds=10,  # 10번 동안 개선이 없으면 중지
    metric_name="auc",  # 모니터링할 평가 지표
    data_name="validation"  # validation set 기준
)

# %%
# 학습 및 Validation 성능 모니터링
eval_set = [(X_train, y_train), (X_val, y_val)]
model.fit(
    X_train, y_train,
    eval_set=eval_set,
    verbose=True,  # 학습 로그 출력
    # early_stopping_rounds=10  # 5번의 학습 동안 성능 개선 없을 시 조기 종료
    
)
# Out:
# [0]	validation_0-auc:0.85771	validation_1-auc:0.65670
# [1]	validation_0-auc:0.89544	validation_1-auc:0.67326
# [2]	validation_0-auc:0.90981	validation_1-auc:0.68084
# [3]	validation_0-auc:0.92602	validation_1-auc:0.68967
# [4]	validation_0-auc:0.93630	validation_1-auc:0.68469
# [5]	validation_0-auc:0.94508	validation_1-auc:0.68863
# [6]	validation_0-auc:0.95141	validation_1-auc:0.69159
# [7]	validation_0-auc:0.95644	validation_1-auc:0.69489
# [8]	validation_0-auc:0.96268	validation_1-auc:0.69589
# [9]	validation_0-auc:0.96669	validation_1-auc:0.69660
# [10]	validation_0-auc:0.97014	validation_1-auc:0.69824
# [11]	validation_0-auc:0.97353	validation_1-auc:0.69934
# [12]	validation_0-auc:0.97556	validation_1-auc:0.70011
# [13]	validation_0-auc:0.97897	validation_1-auc:0.70063
# [14]	validation_0-auc:0.98106	validation_1-auc:0.70174
# [15]	validation_0-auc:0.98339	validation_1-auc:0.70115
# [16]	validation_0-auc:0.98481	validation_1-auc:0.70062
# [17]	validation_0-auc:0.98599	validation_1-auc:0.69946
# [18]	validation_0-auc:0.98733	validation_1-auc:0.70028
# [19]	validation_0-auc:0.98833	validation_1-auc:0.69987
# [20]	validation_0-auc:0.98969	validation_1-auc:0.70055
# [21]	validation_0-auc:0.99042	validation_1-auc:0.70160
# [22]	validation_0-auc:0.99103	validation_1-auc:0.70116
# [23]	validation_0-auc:0.99182	validation_1-auc:0.70297
# [24]	validation_0-auc:0.99232	validation_1-auc:0.70310
# [25]	validation_0-auc:0.99289	validation_1-auc:0.70434
# [26]	validation_0-auc:0.99295	validation_1-auc:0.70459
# [27]	validation_0-auc:0.99342	validation_1-auc:0.70546
# [28]	validation_0-auc:0.99375	validation_1-auc:0.70622
# [29]	validation_0-auc:0.99384	validation_1-auc:0.70580
# [30]	validation_0-auc:0.99464	validation_1-auc:0.70616
# [31]	validation_0-auc:0.99480	validation_1-auc:0.70605
# [32]	validation_0-auc:0.99504	validation_1-auc:0.70671
# [33]	validation_0-auc:0.99523	validation_1-auc:0.70646
# [34]	validation_0-auc:0.99625	validation_1-auc:0.70653
# [35]	validation_0-auc:0.99661	validation_1-auc:0.70662
# [36]	validation_0-auc:0.99673	validation_1-auc:0.70651
# [37]	validation_0-auc:0.99678	validation_1-auc:0.70646
# [38]	validation_0-auc:0.99713	validation_1-auc:0.70614
# [39]	validation_0-auc:0.99724	validation_1-auc:0.70668
# [40]	validation_0-auc:0.99730	validation_1-auc:0.70678
# [41]	validation_0-auc:0.99732	validation_1-auc:0.70637
# [42]	validation_0-auc:0.99759	validation_1-auc:0.70665
# [43]	validation_0-auc:0.99788	validation_1-auc:0.70677
# [44]	validation_0-auc:0.99804	validation_1-auc:0.70651
# [45]	validation_0-auc:0.99815	validation_1-auc:0.70662
# [46]	validation_0-auc:0.99836	validation_1-auc:0.70639
# [47]	validation_0-auc:0.99854	validation_1-auc:0.70704
# [48]	validation_0-auc:0.99862	validation_1-auc:0.70716
# [49]	validation_0-auc:0.99882	validation_1-auc:0.70727
# [50]	validation_0-auc:0.99887	validation_1-auc:0.70736
# [51]	validation_0-auc:0.99897	validation_1-auc:0.70684
# [52]	validation_0-auc:0.99907	validation_1-auc:0.70635
# [53]	validation_0-auc:0.99911	validation_1-auc:0.70702
# [54]	validation_0-auc:0.99922	validation_1-auc:0.70689
# [55]	validation_0-auc:0.99922	validation_1-auc:0.70688
# [56]	validation_0-auc:0.99934	validation_1-auc:0.70712
# [57]	validation_0-auc:0.99939	validation_1-auc:0.70713
# [58]	validation_0-auc:0.99943	validation_1-auc:0.70788
# [59]	validation_0-auc:0.99946	validation_1-auc:0.70787
# [60]	validation_0-auc:0.99956	validation_1-auc:0.70682
# [61]	validation_0-auc:0.99963	validation_1-auc:0.70662
# [62]	validation_0-auc:0.99969	validation_1-auc:0.70746
# [63]	validation_0-auc:0.99970	validation_1-auc:0.70767
# [64]	validation_0-auc:0.99970	validation_1-auc:0.70757
# [65]	validation_0-auc:0.99973	validation_1-auc:0.70776
# [66]	validation_0-auc:0.99975	validation_1-auc:0.70816
# [67]	validation_0-auc:0.99978	validation_1-auc:0.70872
# [68]	validation_0-auc:0.99980	validation_1-auc:0.70895
# [69]	validation_0-auc:0.99983	validation_1-auc:0.70822
# [70]	validation_0-auc:0.99985	validation_1-auc:0.70828
# [71]	validation_0-auc:0.99985	validation_1-auc:0.70823
# [72]	validation_0-auc:0.99987	validation_1-auc:0.70858
# [73]	validation_0-auc:0.99989	validation_1-auc:0.70850
# [74]	validation_0-auc:0.99989	validation_1-auc:0.70866
# [75]	validation_0-auc:0.99991	validation_1-auc:0.70932
# [76]	validation_0-auc:0.99991	validation_1-auc:0.70885
# [77]	validation_0-auc:0.99991	validation_1-auc:0.70888
# [78]	validation_0-auc:0.99992	validation_1-auc:0.70908
# [79]	validation_0-auc:0.99992	validation_1-auc:0.70843
# [80]	validation_0-auc:0.99994	validation_1-auc:0.70838
# [81]	validation_0-auc:0.99994	validation_1-auc:0.70853
# [82]	validation_0-auc:0.99995	validation_1-auc:0.70825
# [83]	validation_0-auc:0.99995	validation_1-auc:0.70842
# [84]	validation_0-auc:0.99995	validation_1-auc:0.70884
# [85]	validation_0-auc:0.99996	validation_1-auc:0.70890
# [86]	validation_0-auc:0.99996	validation_1-auc:0.70862
# [87]	validation_0-auc:0.99997	validation_1-auc:0.70812
# [88]	validation_0-auc:0.99997	validation_1-auc:0.70778
# [89]	validation_0-auc:0.99997	validation_1-auc:0.70807
# [90]	validation_0-auc:0.99998	validation_1-auc:0.70842
# [91]	validation_0-auc:0.99999	validation_1-auc:0.70920
# [92]	validation_0-auc:0.99999	validation_1-auc:0.70920
# [93]	validation_0-auc:0.99999	validation_1-auc:0.70920
# [94]	validation_0-auc:0.99999	validation_1-auc:0.70849
# [95]	validation_0-auc:0.99999	validation_1-auc:0.70930
# [96]	validation_0-auc:0.99999	validation_1-auc:0.70932
# [97]	validation_0-auc:1.00000	validation_1-auc:0.70929
# [98]	validation_0-auc:1.00000	validation_1-auc:0.70964
# [99]	validation_0-auc:1.00000	validation_1-auc:0.70946
# [100]	validation_0-auc:1.00000	validation_1-auc:0.70924
# [101]	validation_0-auc:1.00000	validation_1-auc:0.70885
# [102]	validation_0-auc:1.00000	validation_1-auc:0.70874
# [103]	validation_0-auc:1.00000	validation_1-auc:0.70885
# [104]	validation_0-auc:1.00000	validation_1-auc:0.70903
# [105]	validation_0-auc:1.00000	validation_1-auc:0.70938
# [106]	validation_0-auc:1.00000	validation_1-auc:0.70969
# [107]	validation_0-auc:1.00000	validation_1-auc:0.70980
# [108]	validation_0-auc:1.00000	validation_1-auc:0.70929
# [109]	validation_0-auc:1.00000	validation_1-auc:0.70929
# [110]	validation_0-auc:1.00000	validation_1-auc:0.70986
# [111]	validation_0-auc:1.00000	validation_1-auc:0.71043
# [112]	validation_0-auc:1.00000	validation_1-auc:0.71080
# [113]	validation_0-auc:1.00000	validation_1-auc:0.71117
# [114]	validation_0-auc:1.00000	validation_1-auc:0.71079
# [115]	validation_0-auc:1.00000	validation_1-auc:0.71071
# [116]	validation_0-auc:1.00000	validation_1-auc:0.71039
# [117]	validation_0-auc:1.00000	validation_1-auc:0.71057
# [118]	validation_0-auc:1.00000	validation_1-auc:0.71077
# [119]	validation_0-auc:1.00000	validation_1-auc:0.71049
# [120]	validation_0-auc:1.00000	validation_1-auc:0.71040
# [121]	validation_0-auc:1.00000	validation_1-auc:0.71042
# [122]	validation_0-auc:1.00000	validation_1-auc:0.71044
# [123]	validation_0-auc:1.00000	validation_1-auc:0.71042
# [124]	validation_0-auc:1.00000	validation_1-auc:0.71044
# [125]	validation_0-auc:1.00000	validation_1-auc:0.71012
# [126]	validation_0-auc:1.00000	validation_1-auc:0.71023
# [127]	validation_0-auc:1.00000	validation_1-auc:0.71035
# [128]	validation_0-auc:1.00000	validation_1-auc:0.71041
# [129]	validation_0-auc:1.00000	validation_1-auc:0.70998
# [130]	validation_0-auc:1.00000	validation_1-auc:0.70987
# [131]	validation_0-auc:1.00000	validation_1-auc:0.71034
# [132]	validation_0-auc:1.00000	validation_1-auc:0.71033
# [133]	validation_0-auc:1.00000	validation_1-auc:0.71027
# [134]	validation_0-auc:1.00000	validation_1-auc:0.71066
# [135]	validation_0-auc:1.00000	validation_1-auc:0.71067
# [136]	validation_0-auc:1.00000	validation_1-auc:0.71005
# [137]	validation_0-auc:1.00000	validation_1-auc:0.71011
# [138]	validation_0-auc:1.00000	validation_1-auc:0.71021
# [139]	validation_0-auc:1.00000	validation_1-auc:0.71044
# [140]	validation_0-auc:1.00000	validation_1-auc:0.71054
# [141]	validation_0-auc:1.00000	validation_1-auc:0.71078
# [142]	validation_0-auc:1.00000	validation_1-auc:0.71109
# [143]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [144]	validation_0-auc:1.00000	validation_1-auc:0.71143
# [145]	validation_0-auc:1.00000	validation_1-auc:0.71140
# [146]	validation_0-auc:1.00000	validation_1-auc:0.71161
# [147]	validation_0-auc:1.00000	validation_1-auc:0.71103
# [148]	validation_0-auc:1.00000	validation_1-auc:0.71088
# [149]	validation_0-auc:1.00000	validation_1-auc:0.71095
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.15, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=150, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ## 6. Prediction

# %%
# 채무 불이행 '확률'을 예측합니다.
preds = model.predict_proba(test_df)[:,1]

# %% [markdown]
# ## 7. Submission (제출 파일 생성)

# %%
submit = pd.read_csv('open/sample_submission.csv')

# 결과 저장
submit['채무 불이행 확률'] = preds
submit.to_csv('submission_base2.csv', encoding='UTF-8-sig', index=False)
